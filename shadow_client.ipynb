# %%
# !pip install requests

# %%
from datetime import datetime
import requests

from IPython.display import Image, display


api_endpoint = 'https://gw5lcvggtg.execute-api.us-east-2.amazonaws.com/smart-research/shadow-matrix'
data = {'TOKEN': 'e49c521b1687a97766d82f5770a9c1ac673002578d319882537cd15b54f60adf'}

def get_shadow_matrix():
  print(f"Making post request at {datetime.now()}")
  response = requests.post(api_endpoint, json=data)
  if response.status_code == 200:
      print('POST request successful')
      display(Image(data=response.content))
  else:
      print(f'POST request failed with status code {response.status_code}')

# %%
get_shadow_matrix()
# Out:
# Making post request at 2023-10-15 00:34:46.928123
# POST request successful
